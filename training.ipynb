# %% [markdown]
# <a href="https://colab.research.google.com/github/slomi23/NLP_final_project/blob/main/training.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
! git clone "https://github.com/slomi23/NLP_final_project.git"
# Out:
# fatal: destination path 'NLP_final_project' already exists and is not an empty directory.

# %%
# !cd NLP_final_project/

# %%
# !cd NLP_final_project/

# %%
# !cd NLP_final_project/NLP_final_project
# Out:
# /bin/bash: line 1: cd: NLP_final_project/NLP_final_project: No such file or directory

# %%
# !cd data
# Out:
# /bin/bash: line 1: cd: data: No such file or directory

# %%
# !!git config --global user.name "slomi23"
# Out:
# []

# %%
# !git config --global user.email "slomi23@freeuni.edu.ge"

# %%
# Navigate to your cloned repo
# %cd /content/NLP_final_project

# Fix permissions
# !sudo chown -R $(whoami):$(whoami) /content/NLP_final_project
# !find . -type d -exec chmod 755 {} \;
# !find . -type f -exec chmod 644 {} \;

# Make the repo directory itself writable
# !chmod 755 /content/NLP_final_project
# Out:
# /content/NLP_final_project

# %%
# Check current permissions
# !ls -la /content

# Change ownership of the entire /content directory
# !sudo chown -R $(whoami):$(whoami) /content

# Set appropriate permissions
# !chmod -R 755 /content
# Out:
# total 32
# drwxr-xr-x 1 root root 4096 Jun  7 19:23 .
# drwxr-xr-x 1 root root 4096 Jun  7 18:58 ..
# drwxr-xr-x 1 root root 4096 Jun  4 13:32 .config
# drwxr-xr-x 7 root root 4096 Jun  7 19:23 NLP_final_project
# drwxr-xr-x 1 root root 4096 Jun  4 13:32 sample_data

# %%
from google.colab import drive
drive.mount('/content/drive')
